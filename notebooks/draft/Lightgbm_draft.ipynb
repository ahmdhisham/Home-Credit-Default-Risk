# %% [markdown]
# ### Lightgbm

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size= 0.15, random_state=100, stratify=y)
print("X_train = ",X_train2.shape ," y_train = ", y_train2.shape)
print("X_test  = ",X_test2.shape ," y_test  = ", y_test2.shape)
# Out:
# X_train =  (261379, 24)  y_train =  (261379,)
# X_test  =  (46126, 24)  y_test  =  (46126,)

# %%
X_train2.dropna(inplace=True)
explore(X_train2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222147 entries, 178932 to 35136
# Columns: 120 entries, CNT_CHILDREN to 104
# dtypes: float64(120)
# memory usage: 205.1 MB
# None
#
# Shape: (222147, 120)

# %%
explore(y_train2)
# Out:
# <class 'pandas.core.series.Series'>
# Index: 261379 entries, 178932 to 35136
# Series name: TARGET
# Non-Null Count   Dtype
# --------------   -----
# 261379 non-null  float64
# dtypes: float64(1)
# memory usage: 4.0 MB
# None
#
# Shape: (261379,)

# %%
from sklearn.preprocessing import OneHotEncoder

# Apply One-Hot Encoding
encoder = OneHotEncoder()
X_encoded = pd.DataFrame(encoder.fit_transform(X_train2[cat_columns]).toarray())

# Concatenate with original data
X_train2 = pd.concat([X_train2.drop(cat_columns, axis=1), X_encoded], axis=1)

# Train LightGBM
model2 = lgb.LGBMClassifier()
model2.fit(X_train2, y_train2)
# Out:
# ---------------------------------------------------------------------------
#
# LightGBMError                             Traceback (most recent call last)
#
# Cell In[189], line 12
#
#      10 # Train LightGBM
#
#      11 model2 = lgb.LGBMClassifier()
#
# ---> 12 model2.fit(X_train2, y_train2)
#
#
#
# File c:\Users\ASUS\OneDrive\Desktop\ahmed\NTI\project\.venv\lib\site-packages\lightgbm\sklearn.py:1284, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#
#    1281         else:
#
#    1282             valid_sets.append((valid_x, self._le.transform(valid_y)))
#
# -> 1284 super().fit(
#
#    1285     X,
#
#    1286     _y,
#
#    1287     sample_weight=sample_weight,
#
#    1288     init_score=init_score,
#
#    1289     eval_set=valid_sets,
#
#    1290     eval_names=eval_names,
#
# ...

# %%
import lightgbm as lgb

# Create the LightGBM dataset
train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=cat_columns)

# Train the model
params = {
    'objective': 'binary',
    'metric': 'auc'
}
model = lgb.train(params, train_data)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[187], line 11
#
#       6 # Train the model
#
#       7 params = {
#
#       8     'objective': 'binary',
#
#       9     'metric': 'auc'
#
#      10 }
#
# ---> 11 model = lgb.train(params, train_data)
#
#
#
# File c:\Users\ASUS\OneDrive\Desktop\ahmed\NTI\project\.venv\lib\site-packages\lightgbm\engine.py:282, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#
#     280 # construct booster
#
#     281 try:
#
# --> 282     booster = Booster(params=params, train_set=train_set)
#
#     283     if is_valid_contain_train:
#
#     284         booster.set_train_data_name(train_data_name)
#
#
#
# ...
